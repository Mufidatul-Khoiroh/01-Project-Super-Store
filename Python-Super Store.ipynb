# %% [markdown]
# # **Preparation**

# %% [markdown]
# **Importing Data and Inspection**

# %%
#Import library
import pandas as pd
import numpy as np

#Load data
df = pd.read_excel('/content/SuperStore.xlsx')
print('Top 5 rows:')
display(df.head())

#Data info
print('Shape dataset:')
display(df.shape)

print('\nDataset info:')
display(df.info())

print('\nStatistic info:')
display(df[['Sales','Quantity','Discount','Profit']].describe())

#Checking missing value for each feature
print('Checking missing value for each feature:')
print(df.isnull().any())
# Out:
# Top 5 rows:
#          Order_ID Customer_ID  Postal_Code       Product_ID     Sales  \
# 0  CA-2019-152156    CG-12520        42420  FUR-BO-10001798  261.9600
# 1  CA-2019-152156    CG-12520        42420  FUR-CH-10000454  731.9400
# 2  CA-2019-138688    DV-13045        90036  OFF-LA-10000240   14.6200
# 3  US-2018-108966    SO-20335        33311  FUR-TA-10000577  957.5775
# 4  US-2018-108966    SO-20335        33311  OFF-ST-10000760   22.3680
#
#    Quantity  Discount    Profit         Category Sub-Category  \
# 0         2      0.00   41.9136        Furniture    Bookcases
# 1         3      0.00  219.5820        Furniture       Chairs
# 2         2      0.00    6.8714  Office Supplies       Labels
# 3         5      0.45 -383.0310        Furniture       Tables
# 4         2      0.20    2.5164  Office Supplies      Storage
#
#                                         Product_Name Order_Date  Ship_Date  \
# 0                  Bush Somerset Collection Bookcase 2019-11-08 2019-11-11
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,... 2019-11-08 2019-11-11
# 2  Self-Adhesive Address Labels for Typewriters b... 2019-06-12 2019-06-16
# 3      Bretford CR4500 Series Slim Rectangular Table 2018-10-11 2018-10-18
# 4                     Eldon Fold 'N Roll Cart System 2018-10-11 2018-10-18
#
#         Ship_Mode    Customer_Name    Segment Country/Region             City  \
# 0    Second Class      Claire Gute   Consumer  United States        Henderson
# 1    Second Class      Claire Gute   Consumer  United States        Henderson
# 2    Second Class  Darrin Van Huff  Corporate  United States      Los Angeles
# 3  Standard Class   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4  Standard Class   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#         State Region
# 0    Kentucky  South
# 1    Kentucky  South
# 2  California   West
# 3     Florida  South
# 4     Florida  South
# Shape dataset:
# (9994, 20)
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        9994 non-null   object
#  1   Customer_ID     9994 non-null   object
#  2   Postal_Code     9994 non-null   int64
#  3   Product_ID      9994 non-null   object
#  4   Sales           9994 non-null   float64
#  5   Quantity        9994 non-null   int64
#  6   Discount        9994 non-null   float64
#  7   Profit          9994 non-null   float64
#  8   Category        9994 non-null   object
#  9   Sub-Category    9994 non-null   object
#  10  Product_Name    9994 non-null   object
#  11  Order_Date      9994 non-null   datetime64[ns]
#  12  Ship_Date       9994 non-null   datetime64[ns]
#  13  Ship_Mode       9994 non-null   object
#  14  Customer_Name   9994 non-null   object
#  15  Segment         9994 non-null   object
#  16  Country/Region  9994 non-null   object
#  17  City            9994 non-null   object
#  18  State           9994 non-null   object
#  19  Region          9994 non-null   object
# dtypes: datetime64[ns](2), float64(3), int64(2), object(13)
# memory usage: 1.5+ MB
# None
# Statistic info:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000
# Checking missing value for each feature:
# Order_ID          False
# Customer_ID       False
# Postal_Code       False
# Product_ID        False
# Sales             False
# Quantity          False
# Discount          False
# Profit            False
# Category          False
# Sub-Category      False
# Product_Name      False
# Order_Date        False
# Ship_Date         False
# Ship_Mode         False
# Customer_Name     False
# Segment           False
# Country/Region    False
# City              False
# State             False
# Region            False
# dtype: bool

# %% [markdown]
# **Outlier Detection in Discount Distribution**

# %%
import matplotlib.pyplot as plt

#Define the IQR
Q1 = df['Discount'].quantile(0.25)
Q3 = df['Discount'].quantile(0.75)
IQR = Q3 - Q1

#Determine lower and upper bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

#Outlier identification
outliers = df[(df['Discount'] < lower_bound) | (df['Discount'] > upper_bound)]

#Box plot
plt.boxplot(df['Discount'])
plt.title('Outlier Detection in Discount Distribution')
plt.ylabel('Discount Value (USD)')
plt.show()

# %% [markdown]
# **Outlier Detection in Profit Distribution**

# %%
import matplotlib.pyplot as plt

#Define the IQR
Q1 = df['Profit'].quantile(0.25)
Q3 = df['Profit'].quantile(0.75)
IQR = Q3 - Q1

#Determine lower and upper bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

#Outlier identification
outliers = df[(df['Profit'] < lower_bound) | (df['Profit'] > upper_bound)]

#Box plot
plt.boxplot(df['Profit'])
plt.title('Outlier Detection in Profit Distribution')
plt.ylabel('Profit Value (USD)')
plt.show()

# %% [markdown]
# **Outlier Detection in Quantity Distribution**

# %%
import matplotlib.pyplot as plt

#Define the IQR
Q1 = df['Quantity'].quantile(0.25)
Q3 = df['Quantity'].quantile(0.75)
IQR = Q3 - Q1

#Determine lower and upper bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

#Outlier identification
outliers = df[(df['Quantity'] < lower_bound) | (df['Quantity'] > upper_bound)]

#Box plot
plt.boxplot(df['Quantity'])
plt.title('Outlier Detection in Quantity Distribution')
plt.ylabel('Quantity Value (USD)')
plt.show()

# %% [markdown]
# **Outlier Detection in Sales Distribution**

# %%
import matplotlib.pyplot as plt

#Define the IQR
Q1 = df['Sales'].quantile(0.25)
Q3 = df['Sales'].quantile(0.75)
IQR = Q3 - Q1

#Determine lower and upper bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

#Outlier identification
outliers = df[(df['Sales'] < lower_bound) | (df['Sales'] > upper_bound)]

#Box plot
plt.boxplot(df['Sales'])
plt.title('Outlier Detection in Sales Distribution')
plt.ylabel('Sales Value (USD)')
plt.show()

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**

# %% [markdown]
# **Overview Total Order, Quantity, Sales, and Profit**

# %%
import datetime
import pandas as pd
import numpy as np

#Convert 'Order_Date' to datetime and extract year
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Year'] = df['Order_Date'].dt.year

#Group by 'Year' and calculate sum of 'Quantity', 'Sales' and 'Profit'
df_year = df.groupby('Year').agg({'Quantity': 'sum', 'Sales': 'sum', 'Profit': 'sum'})
display(df_year)
# Out:
#       Quantity        Sales      Profit
# Year
# 2017      7581  484247.4981  49543.9741
# 2018      7979  470532.5090  61618.6037
# 2019      9837  609205.5980  81795.1743
# 2020     12476  733215.2552  93439.2696

# %% [markdown]
# **Trends of Total Sales and Total Profit**

# %%
import datetime
import pandas as pd
import matplotlib.pyplot as plt

#Load data
df = pd.read_excel('/content/SuperStore.xlsx')

#Convert 'Order_Date' to datetime and extract year
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Year'] = df['Order_Date'].dt.year

#Group by 'Year' and calculate sum of 'Sales' and 'Profit'
df_grouped = df.groupby(['Year']).agg({'Sales': 'sum', 'Profit': 'sum'})

#Create the line plot
plt.clf()
df_grouped.plot(
    kind='line',
    color=['blue', 'red'],
    marker='o',
    linewidth=2,
    figsize=(9, 5)
)

#Customize the plot
plt.title('Trends of Total Sales and Total Profit', fontsize=15)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Total Value (USD)', fontsize=12)
plt.xticks(df_grouped.index.astype(int), rotation=0) #Format tick on x-axis

for i, row in df_grouped.iterrows():  #Annotate total value of each point
    plt.annotate(f'{row["Sales"]:.2f}', (i, row["Sales"]), textcoords="offset points", xytext=(0,-20), ha='center',fontsize=8)
    plt.annotate(f'{row["Profit"]:.2f}', (i, row["Profit"]), textcoords="offset points", xytext=(0,10), ha='center', fontsize=8)

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Top 10 Most Profitable Products**

# %%
import pandas as pd
import matplotlib.pyplot as plt

#Load data
df = pd.read_excel('/content/SuperStore.xlsx')

#Grouping data based on Product_Name and Category, and counting total Quantity
grouped_df = df.groupby(['Product_Name', 'Category'])['Profit'].sum().reset_index()

#Sorting data based on Quantity
top_10_profit = grouped_df.sort_values('Profit', ascending=False).head(10)

display(top_10_profit)
# Out:
#                                            Product_Name         Category  \
# 399               Canon imageCLASS 2200 Advanced Copier       Technology
# 638   Fellowes PB500 Electric Punch Plastic Comb Bin...  Office Supplies
# 791                Hewlett Packard LaserJet 3310 Copier       Technology
# 395                  Canon PC1060 Personal Laser Copier       Technology
# 983           Logitech G19 Programmable Gaming Keyboard       Technology
# 773   HP Designjet T520 Inkjet Large Format Printer ...       Technology
# 162                   Ativa V4110MDD Micro-Cut Shredder       Technology
# 19     3D Systems Cube Printer, 2nd Generation, Magenta       Technology
# 881                Ibico EPK-21 Electric Binding System  Office Supplies
# 1807                  Zebra ZM400 Thermal Label Printer       Technology
#
#           Profit
# 399   25199.9280
# 638    7753.0390
# 791    6983.8836
# 395    4570.9347
# 983    4425.3432
# 773    4094.9766
# 162    3772.9461
# 19     3717.9714
# 881    3345.2823
# 1807   3343.5360

# %% [markdown]
# **Top 10 Best-Selling Products based on Quantity**

# %%
import pandas as pd

#Load data
df = pd.read_excel('/content/SuperStore.xlsx')

#Grouping data based on Product_Name and Category, and counting total Quantity
grouped_df = df.groupby(['Product_Name', 'Category'])['Quantity'].sum().reset_index()

#Sorting data based on Quantity
top_10_products = grouped_df.sort_values('Quantity', ascending=False).head(10)

display(top_10_products)
# Out:
#                             Product_Name         Category  Quantity
# 1474                             Staples  Office Supplies       215
# 1468                     Staple envelope  Office Supplies       170
# 530                    Easy-staple paper  Office Supplies       150
# 1475             Staples in misc. colors  Office Supplies        86
# 1009  Logitech P710e Mobile Speakerphone       Technology        75
# 926           KI Adjustable-Height Table        Furniture        74
# 487              DAX Wood Document Frame        Furniture        73
# 255              Avery Non-Stick Binders  Office Supplies        71
# 1486             Storex Dura Pro Binders  Office Supplies        71
# 1635                          Xerox 1881  Office Supplies        70

# %% [markdown]
# **Annual Comparison of Total Sales and Total Profit for Office Supplies**

# %%
import pandas as pd
import matplotlib.pyplot as plt

#Load data
df = pd.read_excel('/content/SuperStore.xlsx')

#Extract Year from Order_Date
df['Year'] = df['Order_Date'].dt.year

#Filtering data for 'Office Supplies' Category
df_OfficeSupplies = df[df['Category'] == 'Office Supplies']

#Grouping data based on Year and aggregating Sales and Profit
grouped_df = df_OfficeSupplies.groupby(['Year']).agg({'Sales': 'sum', 'Profit': 'sum'})

#Create Bar Chart
fig, ax = plt.subplots(figsize=(10, 6))  # Create a figure and axes object

bar_width = 0.35  # Width of the bars

#Create bars for Sales
sales_bars = ax.bar(grouped_df.index - bar_width/2, grouped_df['Sales'], bar_width, label='Sales', color='skyblue')

#Create bars for Profit
profit_bars = ax.bar(grouped_df.index + bar_width/2, grouped_df['Profit'], bar_width, label='Profit', color='red')

#Annotate Sales bars
for bar in sales_bars:
    yval = bar.get_height()
    ax.annotate(f'{yval:.2f}', (bar.get_x() + bar.get_width() / 2, yval),
                ha='center', va='bottom', fontsize=8, xytext=(0, 3),
                textcoords='offset points')

#Annotate Profit bars
for bar in profit_bars:
    yval = bar.get_height()
    ax.annotate(f'{yval:.2f}', (bar.get_x() + bar.get_width() / 2, yval),
                ha='center', va='bottom', fontsize=8, xytext=(0, 3),
                textcoords='offset points')

#Customize the plot
ax.set_title('Annual Comparison of Total Sales and Profit for Office Supplies', fontsize=15)
ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Total Value (USD)', fontsize=12)
ax.set_xticks(grouped_df.index)
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Annual Comparison of Total Sales and Total Profit for Technology

# %%
import pandas as pd
import matplotlib.pyplot as plt

#Load data
df = pd.read_excel('/content/SuperStore.xlsx')

#Extract Year from Order_Date
df['Year'] = df['Order_Date'].dt.year

#Filtering data for 'Technology' Category
df_Technology = df[df['Category'] == 'Technology']

#Grouping data based on Year and aggregating Sales and Profit
grouped_df = df_Technology.groupby(['Year']).agg({'Sales': 'sum', 'Profit': 'sum'})

#Create Bar Chart
fig, ax = plt.subplots(figsize=(10, 6))  # Create a figure and axes object

bar_width = 0.35  # Width of the bars

#Create bars for Sales
sales_bars = ax.bar(grouped_df.index - bar_width/2, grouped_df['Sales'], bar_width, label='Sales', color='skyblue')

#Create bars for Profit
profit_bars = ax.bar(grouped_df.index + bar_width/2, grouped_df['Profit'], bar_width, label='Profit', color='red')

#Annotate Sales bars
for bar in sales_bars:
    yval = bar.get_height()
    ax.annotate(f'{yval:.2f}', (bar.get_x() + bar.get_width() / 2, yval),
                ha='center', va='bottom', fontsize=8, xytext=(0, 3),
                textcoords='offset points')

#Annotate Profit bars
for bar in profit_bars:
    yval = bar.get_height()
    ax.annotate(f'{yval:.2f}', (bar.get_x() + bar.get_width() / 2, yval),
                ha='center', va='bottom', fontsize=8, xytext=(0, 3),
                textcoords='offset points')

#Customize the plot
ax.set_title('Annual Comparison of Total Sales and Profit for Technology', fontsize=15)
ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Total Value (USD)', fontsize=12)
ax.set_xticks(grouped_df.index)
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Profit Achievement of Product Category**

# %% [markdown]
# **Total Profit of Product Category**

# %%
import pandas as pd
import matplotlib.pyplot as plt

#Load data
df = pd.read_excel('/content/SuperStore.xlsx')

#Grouping data based on category and counting total profit
grouped_df = df.groupby('Category')['Profit'].sum().sort_values(ascending=False)

#Create bar chart
plt.clf()
ax = grouped_df.plot(kind='bar', color=['lightgreen', 'yellow', 'coral'])  #Object Axes
plt.title('Total Profit of Product Category', loc='center', pad=10, fontsize=15)
plt.xlabel('Category', fontsize=12)
plt.ylabel('Total Profit (USD)', fontsize=12)
plt.ylim(ymin=0)
plt.xticks(rotation=0)

for p in ax.patches:
    ax.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Profit Proportion of Product Category**

# %%
import pandas as pd
import matplotlib.pyplot as plt

#Profit proportion of product category
profit_by_category = df.groupby('Category')['Profit'].sum()
total_profit = profit_by_category.sum()
profit_proportion = profit_by_category / total_profit

#Create pie chart
plt.figure(figsize=(5,5))
plt.pie(profit_proportion, labels=profit_proportion.index, autopct='%1.1f%%', startangle=140,
        colors = ['coral', 'yellow', 'lightgreen'],
        wedgeprops={'edgecolor': 'white', 'linewidth': 2, 'antialiased': True})
plt.title('Profit Proportion of Product Category', fontsize=15, pad=5)
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Quantity Achievement of Product Category**

# %% [markdown]
# **Total Quantity of Product Category**

# %%
import pandas as pd
import matplotlib.pyplot as plt

#Load data
df = pd.read_excel('/content/SuperStore.xlsx')

#Create bar chart
#Grouping data based on category and counting total profit
plt.clf()
grouped_df=df.groupby('Category')['Quantity'].sum().sort_values(ascending=False)

ax = grouped_df.plot(kind='bar', color=['yellow', 'coral','lightgreen'])  #Object Axes

plt.title('Total Quantity of Product Category', loc='center',pad=10,fontsize=15)
plt.xlabel('Category',fontsize=12)
plt.ylabel('Total Quantity', fontsize=12)

plt.ylim(ymin=0)
plt.xticks(rotation=0)

for p in ax.patches:
    ax.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Quantity Proportion of Product Category**

# %%
import pandas as pd
import matplotlib.pyplot as plt

#Quantity  proportion of product category
Quantity_by_category = df.groupby('Category')['Quantity'].sum()
total_Quantity  = Quantity_by_category.sum()
Quantity_proportion = Quantity_by_category / total_Quantity

# Buat pie chart
plt.figure(figsize=(5,5))
plt.pie(Quantity_proportion, labels=Quantity_proportion.index, autopct='%1.1f%%', startangle=140,
        colors = ['coral', 'yellow', 'lightgreen'],
        wedgeprops={'edgecolor': 'white', 'linewidth': 2, 'antialiased': True})
plt.title('Quantity Proportion of Product Category', fontsize=15, pad=5)
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Total Discount of Product Category**
#
# Counting discount

# %%
import pandas as pd
import matplotlib.pyplot as plt

#Load data
df = pd.read_excel('/content/SuperStore.xlsx')

#Create Bar Chart
#Grouping data based on category and counting total profit
plt.clf()
grouped_df=df.groupby('Category')['Discount'].count().sort_values(ascending=False)

ax = grouped_df.plot(kind='bar',color=['yellow', 'coral','lightgreen'])  #Object Axes

plt.title('Total Discount of Product Category', loc='center',pad=10,fontsize=15)

plt.xlabel('Category',fontsize=12)
plt.ylabel('Total Discount', fontsize=12)

plt.ylim(ymin=0)
plt.xticks(rotation=0)

for p in ax.patches:
    ax.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Monthly Profit Trends in 2020**

# %%
import pandas as pd
import matplotlib.pyplot as plt

#Load data
df = pd.read_excel('/content/SuperStore.xlsx')

#Convert 'Order_Date' to datetime, extract year and month
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Year'] = df['Order_Date'].dt.year
df['Month'] = df['Order_Date'].dt.month

#Filter data for the year 2020
df_2020 = df[df['Year'] == 2020]

#Group by Month and calculate the sum of Profit
monthly_profit_2020 = df_2020.groupby(['Month']).agg({'Profit':'sum'})

#Create the line plot
monthly_profit_2020.plot(
    kind='line',
    color='red',
    marker='o',
    linewidth=2,
    figsize=(10, 5)
)

#Customize the plot
plt.title('Monthly Profit Trends in 2020', fontsize=15)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Total Profit (USD)', fontsize=12)

plt.xticks(range(1, 13))  # Set x-axis ticks for each month

plt.tight_layout()
plt.show()

# %% [markdown]
# **Monthly Discount Trends in 2020**

# %%
#Import library
import pandas as pd

#Load data
df = pd.read_excel('/content/SuperStore.xlsx')

#Convert 'Order_Date' to datetime, extract year and month
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Year'] = df['Order_Date'].dt.year
df['Month'] = df['Order_Date'].dt.month

#Filter data for the year 2020
df_2020 = df[df['Year'] == 2020]

#Group by Month and calculate the sum of Profit
monthly_discount_2020 = df_2020.groupby(['Month']).agg({'Discount':'count'})

#Create the line plot
monthly_discount_2020.plot(
    kind='line',
    color='#A459D1',
    marker='o',
    linewidth=2,
    figsize=(10, 5)
)

#Customize the plot
plt.title('Monthly Discount Trends in 2020', fontsize=15)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Total Discount', fontsize=12)
plt.xticks(range(1, 13))  # Set x-axis ticks for each month
plt.tight_layout()
plt.show()

# %% [markdown]
# **Correlation between Discount, Profit, Quantity, and Sales**
#
# Analysis of discount impact for Profit, Quantity, and Sales

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("/content/SuperStore.xlsx")

numeric_data = df[['Sales','Quantity','Profit','Discount']]

plt.rcParams['figure.dpi'] = 100

# Plot matrix correlation by sns.heatmap
plt.figure()
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm')
plt.title('Matrix Correlation by sns.heatmap', size=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Customer Segmentation Using KMeans**

# %% [markdown]
# **Elbow Method for Cluster Value**

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

#Load data
df = pd.read_excel('/content/SuperStore.xlsx')

#Aggregate data by customer
customer_data = df.groupby('Customer_ID').agg({
    'Sales': 'sum',
    'Quantity': 'sum',
    'Profit': 'sum',
    'Discount':'mean',
    'Order_ID': 'nunique'
}).rename(columns={'Order_ID': 'Frequency'})

#Handle missing values (if any)
customer_data.fillna(0, inplace=True)

#Scale features
scaler = StandardScaler()
scaled_data = scaler.fit_transform(customer_data)

#Calculate WCSS for different cluster numbers
wcss = []
for i in range(1, 11):  #Trying cluster numbers from 1 to 10
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(scaled_data)
    wcss.append(kmeans.inertia_)  #inertia_ is WCSS

#Plot the elbow graph
plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), wcss, marker='o', linestyle='--')
plt.title('Elbow Method')
plt.xlabel('Total Cluster')
plt.ylabel('WCSS')
plt.xticks(range(1, 11))
plt.grid(True, alpha=0.2)
plt.show()

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D  # Import for 3D plotting

#Load data
df = pd.read_excel('/content/SuperStore.xlsx')

#Data aggregations based on Customer_ID
customer_data = df.groupby('Customer_ID').agg({
    'Sales': 'sum',
    'Quantity': 'sum',
    'Profit': 'sum',
    'Discount': 'mean'
}).reset_index()

# Scaling features
scaler = StandardScaler()
scaled_data = scaler.fit_transform(customer_data[['Sales', 'Quantity', 'Profit']]) #Scaling only sales, quantity and profit columns

# KMeans implementation
kmeans = KMeans(n_clusters=3, random_state=42)
customer_data['Cluster'] = kmeans.fit_predict(scaled_data)

# Cluster Visualization (3D scatter plot)
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(customer_data['Sales'], customer_data['Quantity'], customer_data['Profit'], c=customer_data['Cluster'], cmap='viridis')
ax.set_title('Customer Segmentation Using KMeans (3D)')
ax.set_xlabel('Total Sales')
ax.set_ylabel('Total Quantity')
ax.set_zlabel('Total Profit')
ax.legend(*scatter.legend_elements(), title='Cluster')
plt.show()

# Customer segment analysis (focus on Sales, Quantity, Profit)
cluster_summary = customer_data.groupby('Cluster').agg({
    'Sales': 'mean',
    'Quantity': 'mean',
    'Profit': 'mean',
    'Discount': 'mean',
    'Customer_ID': 'count'
}).rename(columns={'Customer_ID': 'Customer Count'})

display(cluster_summary)
# Out:
#                Sales   Quantity       Profit  Discount  Customer Count
# Cluster
# 0        3717.329432  67.689655   375.098646  0.153550             290
# 1        1487.256431  30.997743   104.300547  0.165125             443
# 2        9338.678765  75.183333  2190.221200  0.120049              60

# %% [markdown]
# **Discount Interpretation and Recommendation**

# %%
#Discount Interpretation and Recommendation
print("\nDiscount Interpretation and Recommendation:")
for cluster in cluster_summary.index:
    print(f"\nCluster {cluster}:")
    print(f"  Mean_Sales: {cluster_summary.loc[cluster, 'Sales']:.2f}")
    print(f"  Mean_Quantity: {cluster_summary.loc[cluster, 'Quantity']:.2f}")
    print(f"  Mean_Profit: {cluster_summary.loc[cluster, 'Profit']:.2f}")
    print(f"  Mean_Discount: {cluster_summary.loc[cluster, 'Discount']:.2f}")
    if cluster_summary.loc[cluster, 'Sales'] > customer_data['Sales'].mean():
        print("  Discount Recommendation: Offer fewer discounts or tiered discounts, as these customers have high purchase values.")
    elif cluster_summary.loc[cluster, 'Profit'] < 0 :
        print("  Discount Recommendation: Reduce discounts or review the products purchased by these customers, as they tend to be unprofitable.")
    else :
        print("  Discount Recommendation: Offer moderate discounts to encourage repeat purchases.")
# Out:
# Discount Interpretation and Recommendation:
#
# Cluster 0:
#   Mean_Sales: 3717.33
#   Mean_Quantity: 67.69
#   Mean_Profit: 375.10
#   Mean_Discount: 0.15
#   Discount Recommendation: Offer fewer discounts or tiered discounts, as these customers have high purchase values.
#
# Cluster 1:
#   Mean_Sales: 1487.26
#   Mean_Quantity: 31.00
#   Mean_Profit: 104.30
#   Mean_Discount: 0.17
#   Discount Recommendation: Offer moderate discounts to encourage repeat purchases.
#
# Cluster 2:
#   Mean_Sales: 9338.68
#   Mean_Quantity: 75.18
#   Mean_Profit: 2190.22
#   Mean_Discount: 0.12
#   Discount Recommendation: Offer fewer discounts or tiered discounts, as these customers have high purchase values.
